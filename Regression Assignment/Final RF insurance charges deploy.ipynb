# %%
#Deploy
import pickle
loaded_model=pickle.load(open("finalized_insurancecharge_model_RF.sav",'rb'))
age=int(input("Enter Age:"))
bmi=float(input("Enter BMI:"))
child=int(input("Enter number of children:"))
sex=bool(input("Enter 1 for male/ Enter 0 for female:"))
smoker=bool(input("Enter 1 if smoker otherwise enter 0:"))
result=loaded_model.predict([[age,bmi,child,sex,smoker]])
print("Insurance charge predicted=",float(result))
# Out:
# Enter Age: 28
# Enter BMI: 29.2
# Enter number of children: 2
# Enter 1 for male/ Enter 0 for female: 1
# Enter 1 if smoker otherwise enter 0: 0
# Insurance charge predicted= 18612.690065572824
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Jayashree M\AppData\Local\Temp\ipykernel_24468\1549099284.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Insurance charge predicted=",float(result))
