# %%
#deploy phase for project prediction. Decision Tree Regression algorithm created the best model.
import pickle
loaded_model=pickle.load(open("finalised_model_DT.sav",'rb'))
R_D=float(input("Enter R & D investment"))
Admin=float(input("Enter Administration investment"))
Mar=float(input("Enter Marketing investment"))
S_F=bool(input("Enter 1 if invested in Florida otherwise enter 0"))
S_N=bool(input("Enter 1 if invested in Newyork otherwise enter 0"))
result=loaded_model.predict([[R_D,Admin,Mar,S_F,S_N]])
result
# Out:
# Enter R & D investment 1234
# Enter Administration investment 345
# Enter Marketing investment 4565
# Enter 1 if invested in Florida otherwise enter 0 1
# Enter 1 if invested in Newyork otherwise enter 0 0
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([64926.08])
