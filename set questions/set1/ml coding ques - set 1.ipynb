# %%
#1.
Question 1:A retail store wants to identify customers who make frequent purchases. Given the dataset below, write a Python program to:
Group customers by their IDs.


Calculate the total purchase amount per customer.


Identify the top 3 customers with the highest purchase amounts.


Dataset:
data = {'Customer_ID': [101, 102, 103, 101, 104, 102, 101, 105, 102, 103],
        'Purchase_Amount': [200, 150, 180, 220, 300, 200, 100, 400, 250, 300]}

Expected Output:
Total Purchases per Customer:
   Customer_ID  Purchase_Amount
0          101              520
1          102              600
2          103              480
3          104              300
4          105              400

Top 3 Frequent Customers:
   Customer_ID  Purchase_Amount
1          102              600
0          101              520
2          103              480

# %%
import pandas as pd
data = {'Customer_ID': [101, 102, 103, 101, 104, 102, 101, 105, 102, 103],
        'Purchase_Amount': [200, 150, 180, 220, 300, 200, 100, 400, 250, 300]}
df=pd.DataFrame(data)
df_result = df.groupby('Customer_ID', as_index=False)['Purchase_Amount'].sum()
print(df_result)
top_3_results = df_result.nlargest(3, 'Purchase_Amount')[['Customer_ID', 'Purchase_Amount']]
print(top_3_results)
# Out:
#    Customer_ID  Purchase_Amount
# 0          101              520
# 1          102              600
# 2          103              480
# 3          104              300
# 4          105              400
#    Customer_ID  Purchase_Amount
# 1          102              600
# 0          101              520
# 2          103              480

# %%
#2. Predicting House Prices with Linear Regression
A real estate company wants to predict house prices based on square footage. Write a Python program to:
Train a Linear Regression model.


Predict house prices for given test data.


Dataset:
data = {'Square_Feet': [1500, 2000, 2500, 3000, 3500],
        'Price': [300000, 400000, 500000, 600000, 700000]}

Test Data: [[1800], [2800]]
Expected Output:
Predicted Prices:
[360000. 560000.]

# %%
import pandas as pd
data = {'Square_Feet': [1500, 2000, 2500, 3000, 3500],
        'Price': [300000, 400000, 500000, 600000, 700000]}
dataset=pd.DataFrame(data)
x=dataset[['Square_Feet']]
y=dataset[['Price']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict([[1800],[2800]])
print("Predicted Prices","\n",y_pred)
# Out:
# Predicted Prices
#  [[360000.]
#  [560000.]]
# C:\Users\Jayashree M\.conda\envs\hopeai\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#3:
Identifying Frequent Labels in a Dataset
A company wants to identify the top 3 most common categories in a dataset. Given the dataset below, write a Python program to:
Group the data by Category.


Count the total occurrences of each category.


Identify the top 3 most frequent categories.


Dataset:
data = {'Category': ['A', 'B', 'C', 'A', 'D', 'B', 'A', 'E', 'B', 'C', 'C', 'A'],
        'Value': [10, 15, 20, 30, 25, 18, 22, 40, 35, 50, 45, 15]}

Expected Output:

Total Occurrences per Category:
  Category  Count
0        A      4
1        B      3
2        C      3
3        D      1
4        E      1

Top 3 Frequent Categories:
  Category  Count
0        A      4
1        B      3
2        C      3

# %%
import pandas as pd
data = {'Category': ['A', 'B', 'C', 'A', 'D', 'B', 'A', 'E', 'B', 'C', 'C', 'A'],
        'Value': [10, 15, 20, 30, 25, 18, 22, 40, 35, 50, 45, 15]}
df=pd.DataFrame(data)
df_result = df.groupby('Category', as_index=False)['Value'].count()
print(df_result)
top_3_results = df_result.nlargest(3, 'Value')[['Category', 'Value']]
print(top_3_results)
# Out:
#   Category  Value
# 0        A      4
# 1        B      3
# 2        C      3
# 3        D      1
# 4        E      1
#   Category  Value
# 0        A      4
# 1        B      3
# 2        C      3

# %%
#4.
Predicting Missing Values Using Mean Imputation
A dataset contains missing values in the Age column. Write a Python program to:
Replace missing values with the mean of the column.


Display the updated DataFrame.


Dataset:
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [25, 30, None, 35, None]}

Expected Output:

Original Data:
     Name   Age
0  Alice  25.0
1    Bob  30.0
2 Charlie   NaN
3  David  35.0
4    Eve   NaN

Data after Imputation:
     Name   Age
0  Alice  25.0
1    Bob  30.0
2 Charlie  30.0
3  David  35.0
4    Eve  30.0

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [25, 30, None, 35, None]}

df = pd.DataFrame(data)
print("Original Data")
print(df)
mean_value = df[['Age']].mean()
df.fillna(mean_value,inplace=True)  
print("Data after imputation")
print(df)
# Out:
# Original Data
#       Name   Age
# 0    Alice  25.0
# 1      Bob  30.0
# 2  Charlie   NaN
# 3    David  35.0
# 4      Eve   NaN
# Data after imputation
#       Name   Age
# 0    Alice  25.0
# 1      Bob  30.0
# 2  Charlie  30.0
# 3    David  35.0
# 4      Eve  30.0

# %%
# 5: 
Implementing a Simple Linear Regression Model
You are given a dataset with Experience (years) and Salary ($). Write a Python program to:
Train a Linear Regression model.


Predict the salary for an individual with 6 years of experience.


Dataset:
import pandas as pd

data = {'Experience': [1, 2, 3, 4, 5], 
        'Salary': [30000, 35000, 40000, 45000, 50000]}
df = pd.DataFrame(data)

Expected Output (Example):

Predicted Salary for 6 years of experience: $55000

# %%
###### import pandas as pd
data = {'Experience': [1, 2, 3, 4, 5], 
        'Salary': [30000, 35000, 40000, 45000, 50000]}
dataset=pd.DataFrame(data)
x=dataset[['Experience']]
y=dataset[['Salary']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
n=int(input("Enter the years of experience: "))
exp=reg.predict([[n]])
print("Predicted salary for",n,"years of experience : $",float(exp))
# Out:
# Enter the years of experience:  6
# Predicted salary for 6 years of experience : $ 55000.0
# C:\Users\Jayashree M\.conda\envs\hopeai\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Jayashree M\AppData\Local\Temp\ipykernel_20924\575997711.py:15: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Predicted salary for",n,"years of experience : $",float(exp))

# %%
#6
data = {'word_count': [100, 150, 200, 120, 180, 220], 
        'is_spam': ['ham', 'spam', 'spam', 'ham', 'spam', 'spam']}
df = pd.DataFrame(data)

Expected Output (Example):
Prediction for email with 200 words: Spam

# %%
import pandas as pd
data = {'word_count': [100, 150, 200, 120, 180, 220], 
        'is_spam': ['ham', 'spam', 'spam', 'ham', 'spam', 'spam']}
dataset= pd.DataFrame(data)
dataset=pd.get_dummies(dataset, drop_first=True, dtype=int)
print(dataset)
x=dataset[['word_count']]
y=dataset[['is_spam_spam']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)
n=int(input("Enter the number of words in email: "))
em=classifier.predict([[n]])
if(em==0):
    print("Prediction for email with", n ," words is not Spam")
else:
        print("Prediction for email with", n ," words is Spam")
# Out:
#    word_count  is_spam_spam
# 0         100             0
# 1         150             1
# 2         200             1
# 3         120             0
# 4         180             1
# 5         220             1
# C:\Users\Jayashree M\.conda\envs\hopeai\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Enter the number of words in email:  200
# Prediction for email with 200  words is Spam
# C:\Users\Jayashree M\.conda\envs\hopeai\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
